# %%
import numpy as np
import pandas as pd

# %%
#'Public health unit.xlsx'
phu = pd.read_excel('Public health unit.xlsx', engine='openpyxl', sheet_name = 'Public health unit')
phu
# Out:
#     PHU_ID                                      Reporting_PHU  \
# 0     2244                       Middlesex-London Health Unit
# 1     2236                    Halton Region Health Department
# 2     3895                              Toronto Public Health
# 3     5183                   Huron Perth District Health Unit
# 4     2266           Wellington-Dufferin-Guelph Public Health
# 5     2263                            Timiskaming Health Unit
# 6     2262                   Thunder Bay District Health Unit
# 7     2253                                 Peel Public Health
# 8     2261                     Sudbury & District Health Unit
# 9     2230                    Durham Region Health Department
# 10    2237                    Hamilton Public Health Services
# 11    2268                   Windsor-Essex County Health Unit
# 12    2265                  Region of Waterloo, Public Health
# 13    2260                Simcoe Muskoka District Health Unit
# 14    4913                         Southwestern Public Health
# 15    2226                          Algoma Public Health Unit
# 16    2243   Leeds, Grenville and Lanark District Health Unit
# 17    2238    Hastings and Prince Edward Counties Health Unit
# 18    2247         North Bay Parry Sound District Health Unit
# 19    2270                 York Region Public Health Services
# 20    2249                           Northwestern Health Unit
# 21    2255                         Peterborough Public Health
# 22    2233                             Grey Bruce Health Unit
# 23    2241  Kingston, Frontenac and Lennox & Addington Pub...
# 24    2256                              Porcupine Health Unit
# 25    2257            Renfrew County and District Health Unit
# 26    2251                               Ottawa Public Health
# 27    2227                           Brant County Health Unit
# 28    2234                      Haldimand-Norfolk Health Unit
# 29    2235  Haliburton, Kawartha, Pine Ridge District Heal...
# 30    2246            Niagara Region Public Health Department
# 31    2258                        Eastern Ontario Health Unit
# 32    2242                              Lambton Public Health
# 33    2240                           Chatham-Kent Health Unit
# 34    2244                       Middlesex-London Health Unit
#
#              Reporting_PHU_Address Reporting_PHU_City  \
# 0                   50 King Street             London
# 1                 1151 Bronte Road           Oakville
# 2   277 Victoria Street, 5th Floor            Toronto
# 3             653 West Gore Street          Stratford
# 4              160 Chancellors Way             Guelph
# 5    247 Whitewood Avenue, Unit 43       New Liskeard
# 6              999 Balmoral Street        Thunder Bay
# 7           7120 Hurontario Street        Mississauga
# 8                1300 Paris Street            Sudbury
# 9           605 Rossland Road East             Whitby
# 10    110 King St. West, 2nd Floor           Hamilton
# 11           1005 Ouellette Avenue            Windsor
# 12          99 Regina Street South           Waterloo
# 13               15 Sperling Drive             Barrie
# 14              1230 Talbot Street         St. Thomas
# 15               294 Willow Avenue   Sault Ste. Marie
# 16           458 Laurier Boulevard         Brockville
# 17           179 North Park Street         Belleville
# 18             345 Oak Street West          North Bay
# 19              17250 Yonge Street          Newmarket
# 20          210 First Street North             Kenora
# 21                 185 King Street       Peterborough
# 22            101 17th Street East         Owen Sound
# 23           221 Portsmouth Avenue           Kingston
# 24           169 Pine Street South            Timmins
# 25           7 International Drive           Pembroke
# 26         100 Constellation Drive             Ottawa
# 27         194 Terrace Hill Street          Brantford
# 28             12 Gilbertson Drive             Simcoe
# 29              200 Rose Glen Road          Port Hope
# 30        1815 Sir Isaac Brock Way            Thorold
# 31                1000 Pitt Street           Cornwall
# 32              160 Exmouth Street       Point Edward
# 33           435 Grand Avenue West            Chatham
# 34                  50 King Street             London
#
#    Reporting_PHU_Postal_Code  \
# 0                    N6A 5L7
# 1                    L6M 3Ll
# 2                    M5B 1W2
# 3                    N5A 1L4
# 4                    N1G 0E1
# 5                    P0J 1P0
# 6                    P7B 6E7
# 7                    L5W 1N4
# 8                    P3E 3A3
# 9                    L1N 0B2
# 10                   L8P 4S6
# 11                   N9A 4J8
# 12                   N2J 4V3
# 13                   L4M 6K9
# 14                   N5P 1G9
# 15                   P6B 0A9
# 16                   K6V 7A3
# 17                   K8P 4P1
# 18                   P1B 2T2
# 19                   L3Y 6Z1
# 20                   P9N 2K4
# 21                   K9J 2R8
# 22                   N4K 0A5
# 23                   K7M 1V5
# 24                   P4N 8B7
# 25                   K8A 6W5
# 26                   K2G 6J8
# 27                   N3R 1G7
# 28                   N3Y 4N5
# 29                   L1A 3V6
# 30                   L2V 4T7
# 31                   K6J 5T1
# 32                   N7T 7Z6
# 33                   N7M 5L8
# 34                   N6A 5L7
#
#                                 Reporting_PHU_Website  Reporting_PHU_Latitude  \
# 0                                  www.healthunit.com              4299571559
# 1          www.halton.ca/For-Residents/Public-Health/              4351209709
# 2   www.toronto.ca/community-people/health-wellnes...              4372584482
# 3                                         www.hpph.ca              4360051407
# 4                              www.wdgpublichealth.ca              4385364154
# 5                               www.timiskaminghu.com              4765305799
# 6                                       www.tbdhu.com              5239724709
# 7                           www.peelregion.ca/health/              4376161337
# 8                                         www.phsd.ca              4784651445
# 9   www.durham.ca/en/health-and-wellness/health-an...              4403514967
# 10                       www.hamilton.ca/publichealth              4325324313
# 11                                      www.wechu.org              4215642327
# 12                            www.regionofwaterloo.ca              4346283583
# 13                        www.simcoemuskokahealth.org              4477775463
# 14                              www.swpublichealth.ca              4298933013
# 15                         www.algomapublichealth.com               475967893
# 16                                 www.healthunit.org              4486378244
# 17                             www.hpePublicHealth.ca              4463116714
# 18                                www.myhealthunit.ca              4608538431
# 19            www.york.ca/wps/portal/yorkhome/health/              4407497664
# 20                                     www.nwhu.on.ca              5149480889
# 21                    www.peterboroughpublichealth.ca              4453667727
# 22                   www.publichealthgreybruce.on.ca/              4440827896
# 23                                      www.kflaph.ca              4467675443
# 24                              www.porcupinehu.on.ca              5185310322
# 25                                      www.rcdhu.com              4580633371
# 26                          www.ottawapublichealth.ca              4517957839
# 27                                      www.bchu.org/              4312034629
# 28                                       www.hnhu.org              4285444671
# 29                                    www.hkpr.on.ca/              4467123794
# 30                        www.niagararegion.ca/health                43045446
# 31                                        www.eohu.ca               452730605
# 32                            www.lambtonhealth.on.ca              4288627513
# 33                                      www.ckphu.com              4241925325
# 34                                 www.healthunit.com              4299571559
#
#     Reporting_PHU_Longitude
# 0                -814569832
# 1               -7989050809
# 2               -7938955775
# 3               -8128148453
# 4               -8037208498
# 5               -8021524027
# 6               -8853140488
# 7               -7981357092
# 8               -8304716571
# 9               -7888249823
# 10              -7995846342
# 11              -8277753253
# 12              -8053867571
# 13              -7954577339
# 14              -8078600768
# 15              -8441246863
# 16              -7611805844
# 17              -7755186057
# 18              -7968682329
# 19              -7942821218
# 20              -9255345583
# 21              -7821233161
# 22              -8100861061
# 23              -7688425424
# 24              -8351577643
# 25               -777769518
# 26              -7579995195
# 27              -8029538881
# 28              -8017803538
# 29              -7889722192
# 30              -7931367036
# 31              -7495257873
# 32               -820983725
# 33              -8212808769
# 34               -814569832

# %%
caserp = pd.read_csv('Cases Report.csv')
caserp
# Out:
#         Outcome  Age  Gender                       Reporting PHU SpecimenDate  \
# 0      Resolved  80s  FEMALE               Toronto Public Health    9/24/2020
# 1      Resolved  <20    MALE                  Peel Public Health   12/24/2020
# 2      Resolved  20s    MALE               Lambton Public Health    9/23/2020
# 3      Resolved  20s    MALE   Region of Waterloo, Public Health    9/20/2020
# 4      Resolved  20s  FEMALE                Ottawa Public Health    9/21/2020
# ...         ...  ...     ...                                 ...          ...
# 28495  Resolved  70s  FEMALE  York Region Public Health Services    2/29/2020
# 28496  Resolved  50s    MALE  York Region Public Health Services    2/28/2020
# 28497  Resolved  50s  FEMALE     Durham Region Health Department    2/28/2020
# 28498  Resolved  60s    MALE     Durham Region Health Department    2/28/2020
# 28499  Resolved  40s    MALE  York Region Public Health Services    2/29/2020
#
#       CaseReported Date       PHUCity TestReported Date CaseAcquisition info  \
# 0              2/6/2021       Toronto          2/6/2021                   OB
# 1              2/1/2021   Mississauga          2/1/2021                   CC
# 2             1/15/2021  Point Edward         1/14/2021                   CC
# 3            12/29/2020      Waterloo         9/23/2020    NO KNOWN EPI LINK
# 4            12/24/2020        Ottawa         9/22/2020                   CC
# ...                 ...           ...               ...                  ...
# 28495         2/29/2020     Newmarket          3/1/2020               TRAVEL
# 28496         2/28/2020     Newmarket          3/2/2020               TRAVEL
# 28497         2/28/2020        Whitby         2/28/2020               TRAVEL
# 28498         2/28/2020        Whitby         2/28/2020                   CC
# 28499         2/28/2020     Newmarket          3/1/2020               TRAVEL
#
#       AccurateEpisode Dt                     PHU Address  \
# 0              1/26/2021  277 Victoria Street, 5th Floor
# 1              1/29/2021          7120 Hurontario Street
# 2              1/10/2021              160 Exmouth Street
# 3              9/20/2020          99 Regina Street South
# 4              9/21/2020         100 Constellation Drive
# ...                  ...                             ...
# 28495          2/22/2020              17250 Yonge Street
# 28496          2/27/2020              17250 Yonge Street
# 28497          2/24/2020          605 Rossland Road East
# 28498          2/26/2020          605 Rossland Road East
# 28499          2/28/2020              17250 Yonge Street
#
#                                              PHU Website OutbreakRelated  \
# 0      www.toronto.ca/community-people/health-wellnes...             Yes
# 1                              www.peelregion.ca/health/             NaN
# 2                                www.lambtonhealth.on.ca             Yes
# 3                                www.regionofwaterloo.ca             NaN
# 4                              www.ottawapublichealth.ca             NaN
# ...                                                  ...             ...
# 28495           www.york.ca/wps/portal/yorkhome/health/              NaN
# 28496           www.york.ca/wps/portal/yorkhome/health/              NaN
# 28497  www.durham.ca/en/health-and-wellness/health-an...             NaN
# 28498  www.durham.ca/en/health-and-wellness/health-an...             NaN
# 28499           www.york.ca/wps/portal/yorkhome/health/              NaN
#
#        PHU Latitude  PHU Longitude PHU Postal Code
# 0         43.656591     -79.379358         M5B 1W2
# 1         43.647471     -79.708893         L5W 1N4
# 2         42.986416     -82.404808         N7T 7Z6
# 3         43.462876     -80.520913         N2J 4V3
# 4         45.345665     -75.763912         K2G 6J8
# ...             ...            ...             ...
# 28495     44.048023     -79.480239         L3Y 6Z1
# 28496     44.048023     -79.480239         L3Y 6Z1
# 28497     43.898605     -78.940341         L1N 0B2
# 28498     43.898605     -78.940341         L1N 0B2
# 28499     44.048023     -79.480239         L3Y 6Z1
#
# [28500 rows x 16 columns]

# %%
phu = phu.astype({"Reporting_PHU_Latitude": float, "Reporting_PHU_Longitude": float})
phu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PHU_ID                     35 non-null     int64
#  1   Reporting_PHU              35 non-null     object
#  2   Reporting_PHU_Address      35 non-null     object
#  3   Reporting_PHU_City         35 non-null     object
#  4   Reporting_PHU_Postal_Code  35 non-null     object
#  5   Reporting_PHU_Website      35 non-null     object
#  6   Reporting_PHU_Latitude     35 non-null     float64
#  7   Reporting_PHU_Longitude    35 non-null     float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 2.3+ KB

# %%
lat = pd.DataFrame(caserp, columns=['Reporting PHU', 'PHU Latitude', 'PHU Longitude'])
lat = lat.rename(columns={'Reporting PHU':'Reporting_PHU'})
lat.drop_duplicates( inplace=True)
lat
# Out:
#                                           Reporting_PHU  PHU Latitude  \
# 0                                 Toronto Public Health     43.656591
# 1                                    Peel Public Health     43.647471
# 2                                 Lambton Public Health     42.986416
# 3                     Region of Waterloo, Public Health     43.462876
# 4                                  Ottawa Public Health     45.345665
# 5                    York Region Public Health Services     44.048023
# 6                       Durham Region Health Department     43.898605
# 10              Renfrew County and District Health Unit     45.799406
# 14                      Hamilton Public Health Services     43.257631
# 16                      Halton Region Health Department     43.413997
# 18              Niagara Region Public Health Department     43.116537
# 29                     Windsor-Essex County Health Unit     42.308796
# 30                  Simcoe Muskoka District Health Unit     44.410713
# 50                            Algoma Public Health Unit     46.532373
# 63             Wellington-Dufferin-Guelph Public Health     43.524881
# 94    Kingston, Frontenac and Lennox & Addington Pub...     44.227874
# 109                         Eastern Ontario Health Unit     45.029152
# 148                               Porcupine Health Unit     48.472510
# 267          North Bay Parry Sound District Health Unit     46.313207
# 276                            Brant County Health Unit     43.151811
# 317                          Peterborough Public Health     44.301632
# 378                       Haldimand-Norfolk Health Unit     42.847825
# 405    Leeds, Grenville and Lanark District Health Unit     44.615843
# 484   Haliburton, Kawartha, Pine Ridge District Heal...     43.968173
# 645                        Middlesex-London Health Unit     42.981468
# 806                    Huron Perth District Health Unit     43.368662
# 836                              Grey Bruce Health Unit     44.576196
# 906     Hastings and Prince Edward Counties Health Unit     44.186674
# 925                            Chatham-Kent Health Unit     42.403861
# 1158                           Northwestern Health Unit     49.769615
# 1696                   Thunder Bay District Health Unit     48.400572
# 1730                         Southwestern Public Health     42.777804
# 1751                     Sudbury & District Health Unit     46.466092
# 2564                            Timiskaming Health Unit     47.509284
#
#       PHU Longitude
# 0        -79.379358
# 1        -79.708893
# 2        -82.404808
# 3        -80.520913
# 4        -75.763912
# 5        -79.480239
# 6        -78.940341
# 10       -77.118727
# 14       -79.871341
# 16       -79.744796
# 18       -79.241220
# 29       -83.033670
# 30       -79.686306
# 50       -84.314836
# 63       -80.233743
# 94       -76.525211
# 109      -74.736298
# 148      -81.328750
# 267      -79.467840
# 276      -80.274374
# 317      -78.321347
# 378      -80.303815
# 405      -75.702833
# 484      -78.285792
# 645      -81.254016
# 806      -81.001913
# 836      -80.940980
# 906      -77.391446
# 925      -82.208561
# 1158     -94.488254
# 1696     -89.258851
# 1730     -81.151156
# 1751     -80.998059
# 2564     -79.681632

# %%
caserp[caserp['Reporting PHU'].isin(phu.Reporting_PHU)]['PHU Latitude'].values
# Out:
# array([43.65659125, 43.6474713 , 42.98641646, ..., 43.898605  ,
#        43.898605  , 44.048023  ])

# %%
result = pd.merge(phu, lat, how="inner", on=["Reporting_PHU"])
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PHU_ID                     35 non-null     int64
#  1   Reporting_PHU              35 non-null     object
#  2   Reporting_PHU_Address      35 non-null     object
#  3   Reporting_PHU_City         35 non-null     object
#  4   Reporting_PHU_Postal_Code  35 non-null     object
#  5   Reporting_PHU_Website      35 non-null     object
#  6   Reporting_PHU_Latitude     35 non-null     float64
#  7   Reporting_PHU_Longitude    35 non-null     float64
#  8   PHU Latitude               35 non-null     float64
#  9   PHU Longitude              35 non-null     float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.0+ KB

# %%
result['Reporting_PHU_Latitude']=result['PHU Latitude']
result['Reporting_PHU_Longitude']=result['PHU Longitude']

# %%
result.drop(columns='PHU Latitude', inplace=True)
result.drop(columns='PHU Longitude', inplace=True)

# %%
result['CreatedDate']=pd.datetime.now()
result['UpdatedDate']=pd.datetime.now()
result.columns
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13216\1791874375.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   result['CreatedDate']=pd.datetime.now()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13216\1791874375.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   result['UpdatedDate']=pd.datetime.now()
# Index(['PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address',
#        'Reporting_PHU_City', 'Reporting_PHU_Postal_Code',
#        'Reporting_PHU_Website', 'Reporting_PHU_Latitude',
#        'Reporting_PHU_Longitude', 'CreatedDate', 'UpdatedDate'],
#       dtype='object')

# %%
result.drop_duplicates(inplace=True)

# %%
result.columns=['PHUID', 'ReportingPHU', 'ReportingPHUAddress',
       'ReportingPHUCity', 'ReportingPHUPostalCode',
       'ReportingPHUWebsite', 'ReportingPHULatitude',
       'ReportingPHULongitude', 'CreatedDate', 'UpdatedDate']
result.to_excel('PublicHealthUnit.xlsx',index=False)

# %%
#'Public Health Units GROUP.xlsx'
phugr = pd.read_excel('Public Health Units GROUP.xlsx', engine='openpyxl')
phugr
# Out:
#                            PHU_Group          PHU_City  \
# 0                            Central           Toronto
# 1                            Central         Newmarket
# 2                       Central East     Durham Region
# 3                       Central East         Port Hope
# 4                       Central East      Peterborough
# 5                       Central West            Fergus
# 6                          Champlain          Cornwall
# 7                          Champlain        Brockville
# 8                          Champlain            Ottawa
# 9                          Champlain          Pembroke
# 10                    Erie St. Clair           Chatham
# 11                    Erie St. Clair      Point Edward
# 12                    Erie St. Clair           Windsor
# 13  Hamilton Niagara Haldimand Brant         Brantford
# 14  Hamilton Niagara Haldimand Brant            Simcoe
# 15  Hamilton Niagara Haldimand Brant          Oakville
# 16  Hamilton Niagara Haldimand Brant          Hamilton
# 17  Hamilton Niagara Haldimand Brant           Thorold
# 18                Mississauga Halton       Mississauga
# 19                        North East  Sault Ste. Marie
# 20                        North East         North Bay
# 21                        North East            Kenora
# 22                        North East           Timmins
# 23                        North East           Sudbury
# 24                        North East      New Liskeard
# 25              North Simcoe Muskoka        Owen Sound
# 26              North Simcoe Muskoka            Barrie
# 27                        North West       Thunder Bay
# 28                        South East        Belleville
# 29                        South East          Kingston
# 30                        South West         Stratford
# 31                        South West            London
# 32                        South West        St. Thomas
# 33               Waterloo Wellington          Waterloo
#
#                                            PHU_region
# 0                               Toronto Public Health
# 1                  York Region Public Health Services
# 2                     Durham Region Health Department
# 3   Haliburton, Kawartha, Pine Ridge District Heal...
# 4                          Peterborough Public Health
# 5              Wellington-Dufferin-Guelph Health Unit
# 6                         Eastern Ontario Health Unit
# 7    Leeds, Grenville and Lanark District Health Unit
# 8                                Ottawa Public Health
# 9             Renfrew County and District Health Unit
# 10                           Chatham-Kent Health Unit
# 11                                Lambton Health Unit
# 12                   Windsor-Essex County Health Unit
# 13                           Brant County Health Unit
# 14                      Haldimand-Norfolk Health Unit
# 15                    Halton Region Health Department
# 16                    Hamilton Public Health Services
# 17            Niagara Region Public Health Department
# 18                                 Peel Public Health
# 19                          Algoma Public Health Unit
# 20         North Bay Parry Sound District Health Unit
# 21                           Northwestern Health Unit
# 22                              Porcupine Health Unit
# 23                   Sudbury and District Health Unit
# 24                            Timiskaming Health Unit
# 25                             Grey Bruce Health Unit
# 26                Simcoe Muskoka District Health Unit
# 27                   Thunder Bay District Health Unit
# 28    Hastings and Prince Edward Counties Health Unit
# 29  Kingston, Frontenac and Lennox & Addington Hea...
# 30                            Huron Perth Health Unit
# 31                       Middlesex-London Health Unit
# 32                         Southwestern Public Health
# 33                  Region of Waterloo, Public Health

# %%
phugr['CreatedDate']=pd.datetime.now()
phugr['UpdatedDate']=pd.datetime.now()
phugr.columns
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13216\4061087990.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   phugr['CreatedDate']=pd.datetime.now()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13216\4061087990.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   phugr['UpdatedDate']=pd.datetime.now()
# Index(['PHU_Group', 'PHU_City', 'PHU_region', 'CreatedDate', 'UpdatedDate'], dtype='object')

# %%
phugr.columns=['PHUGroup', 'PHUCity', 'PHURegion', 'CreatedDate', 'UpdatedDate']
phugr.to_excel('PublicHealthUnitsGroup.xlsx',index=False)

# %%
#'vaccines_by_age_phu.csv'
vaccine = pd.read_csv('vaccines_by_age_phu.csv', delimiter=';')
vaccine
# Out:
#                        Date  PHUID      AgeGroup  \
# 0       2021-07-26 00:00:00   2226         12-17
# 1       2021-07-26 00:00:00   2227         12-17
# 2       2021-07-26 00:00:00   2230         12-17
# 3       2021-07-26 00:00:00   2233         12-17
# 4       2021-07-26 00:00:00   2234         12-17
# ...                     ...    ...           ...
# 171177  2022-08-25 00:00:00   2270  Not reported
# 171178  2022-08-25 00:00:00   3895  Not reported
# 171179  2022-08-25 00:00:00   4913  Not reported
# 171180  2022-08-25 00:00:00   5183  Not reported
# 171181  2022-08-25 00:00:00   9999  Not reported
#
#         At_least_one_dose_cumulative  Second_dose_cumulative  \
# 0                             3843.0                  1890.0
# 1                             6306.0                  3567.0
# 2                            34025.0                 16953.0
# 3                             5533.0                  3627.0
# 4                             3125.0                  1711.0
# ...                              ...                     ...
# 171177                        1856.0                     NaN
# 171178                        7393.0                     NaN
# 171179                         200.0                     NaN
# 171180                         250.0                     NaN
# 171181                         100.0                     NaN
#
#         fully_vaccinated_cumulative  third_dose_cumulative  \
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 171177                         40.0                    0.0
# 171178                        216.0                   14.0
# 171179                          2.0                    0.0
# 171180                          2.0                    0.0
# 171181                         54.0                    6.0
#
#                 CreatedDate          UpdatedDate
# 0       2022-11-22 22:33:33  2022-11-22 22:33:33
# 1       2022-11-22 22:33:33  2022-11-22 22:33:33
# 2       2022-11-22 22:33:33  2022-11-22 22:33:33
# 3       2022-11-22 22:33:33  2022-11-22 22:33:33
# 4       2022-11-22 22:33:33  2022-11-22 22:33:33
# ...                     ...                  ...
# 171177  2022-11-22 22:33:33  2022-11-22 22:33:33
# 171178  2022-11-22 22:33:33  2022-11-22 22:33:33
# 171179  2022-11-22 22:33:33  2022-11-22 22:33:33
# 171180  2022-11-22 22:33:33  2022-11-22 22:33:33
# 171181  2022-11-22 22:33:33  2022-11-22 22:33:33
#
# [171182 rows x 9 columns]

# %%
vaccine.loc[vaccine['AgeGroup']=='05-11yrs','AgeGroup'] = '05-11'
vaccine.loc[vaccine['AgeGroup']=='12-17yrs','AgeGroup'] = '12-17'
vaccine.loc[vaccine['AgeGroup']=='18-29yrs','AgeGroup'] = '18-29'
vaccine.loc[vaccine['AgeGroup']=='30-39yrs','AgeGroup'] = '30-39'
vaccine.loc[vaccine['AgeGroup']=='40-49yrs','AgeGroup'] = '40-49'
vaccine.loc[vaccine['AgeGroup']=='50-59yrs','AgeGroup'] = '50-59'
vaccine.loc[vaccine['AgeGroup']=='60-69yrs','AgeGroup'] = '60-69'
vaccine.loc[vaccine['AgeGroup']=='70-79yrs','AgeGroup'] = '70-79'
vaccine.loc[vaccine['AgeGroup']=='Undisclosed_or_missing','AgeGroup'] = 'Not reported'

# %%
vaccine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171182 entries, 0 to 171181
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date                          171182 non-null  object
#  1   PHUID                         171182 non-null  int64
#  2   AgeGroup                      171182 non-null  object
#  3   At_least_one_dose_cumulative  170971 non-null  float64
#  4   Second_dose_cumulative        48642 non-null   float64
#  5   fully_vaccinated_cumulative   121912 non-null  float64
#  6   third_dose_cumulative         106015 non-null  float64
#  7   CreatedDate                   171182 non-null  object
#  8   UpdatedDate                   171182 non-null  object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 11.8+ MB

# %%
vaccine.drop(vaccine[vaccine.PHUID == 9999].index, inplace=True)

# %%
vaccine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166317 entries, 0 to 171180
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date                          166317 non-null  object
#  1   PHUID                         166317 non-null  int64
#  2   AgeGroup                      166317 non-null  object
#  3   At_least_one_dose_cumulative  166113 non-null  float64
#  4   Second_dose_cumulative        47240 non-null   float64
#  5   fully_vaccinated_cumulative   118456 non-null  float64
#  6   third_dose_cumulative         102986 non-null  float64
#  7   CreatedDate                   166317 non-null  object
#  8   UpdatedDate                   166317 non-null  object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 12.7+ MB

# %%
vaccine['CreatedDate']=pd.datetime.now()
vaccine['UpdatedDate']=pd.datetime.now()
vaccine['Date'] =  pd.to_datetime(vaccine['Date'], format='%Y/%m/%d %H:%M:%S')
vaccine
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13216\3490450924.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   vaccine['CreatedDate']=pd.datetime.now()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_13216\3490450924.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   vaccine['UpdatedDate']=pd.datetime.now()
#              Date  PHUID      AgeGroup  At_least_one_dose_cumulative  \
# 0      2021-07-26   2226         12-17                        3843.0
# 1      2021-07-26   2227         12-17                        6306.0
# 2      2021-07-26   2230         12-17                       34025.0
# 3      2021-07-26   2233         12-17                        5533.0
# 4      2021-07-26   2234         12-17                        3125.0
# ...           ...    ...           ...                           ...
# 171177 2022-08-25   2270  Not reported                        1856.0
# 171178 2022-08-25   3895  Not reported                        7393.0
# 171179 2022-08-25   4913  Not reported                         200.0
# 171180 2022-08-25   5183  Not reported                         250.0
# 171181 2022-08-25   9999  Not reported                         100.0
#
#         Second_dose_cumulative  fully_vaccinated_cumulative  \
# 0                       1890.0                          NaN
# 1                       3567.0                          NaN
# 2                      16953.0                          NaN
# 3                       3627.0                          NaN
# 4                       1711.0                          NaN
# ...                        ...                          ...
# 171177                     NaN                         40.0
# 171178                     NaN                        216.0
# 171179                     NaN                          2.0
# 171180                     NaN                          2.0
# 171181                     NaN                         54.0
#
#         third_dose_cumulative                CreatedDate  \
# 0                         NaN 2022-11-23 11:32:32.883413
# 1                         NaN 2022-11-23 11:32:32.883413
# 2                         NaN 2022-11-23 11:32:32.883413
# 3                         NaN 2022-11-23 11:32:32.883413
# 4                         NaN 2022-11-23 11:32:32.883413
# ...                       ...                        ...
# 171177                    0.0 2022-11-23 11:32:32.883413
# 171178                   14.0 2022-11-23 11:32:32.883413
# 171179                    0.0 2022-11-23 11:32:32.883413
# 171180                    0.0 2022-11-23 11:32:32.883413
# 171181                    6.0 2022-11-23 11:32:32.883413
#
#                       UpdatedDate
# 0      2022-11-23 11:32:32.890939
# 1      2022-11-23 11:32:32.890939
# 2      2022-11-23 11:32:32.890939
# 3      2022-11-23 11:32:32.890939
# 4      2022-11-23 11:32:32.890939
# ...                           ...
# 171177 2022-11-23 11:32:32.890939
# 171178 2022-11-23 11:32:32.890939
# 171179 2022-11-23 11:32:32.890939
# 171180 2022-11-23 11:32:32.890939
# 171181 2022-11-23 11:32:32.890939
#
# [171182 rows x 9 columns]

# %%
vaccine.columns
# Out:
# Index(['Date', 'PHUID', 'AgeGroup', 'At_least_one_dose_cumulative',
#        'Second_dose_cumulative', 'fully_vaccinated_cumulative',
#        'third_dose_cumulative', 'CreatedDate', 'UpdatedDate'],
#       dtype='object')

# %%
vaccine.columns=['Date', 'PHUID', 'AgeGroup', 'At_least_one_dose_cumulative',
       'Second_dose_cumulative', 'fully_vaccinated_cumulative',
       'third_dose_cumulative', 'CreatedDate', 'UpdatedDate']
vaccine.to_excel('VaccinesByAgePHU.xlsx',index=False)
